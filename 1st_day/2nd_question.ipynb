# %%
num1=int(input("enter first number:"))
num2=int(input("enter second number:"))
s=num1+num2
lst=[1,3,5,7,9,11,12,23,43,56,87,23,89,332,567,909]
lst_indexMid=int(len(lst)/2)
print(lst_indexMid)
lst_indexValue=lst[lst_indexMid]
print(lst_indexValue,s)

print(set(lst[i] for i in range(0,lst_indexMid) if s < lst_indexMid))
print({lst_indexMid:lst_indexValue} if s == lst_indexValue else {})
print((lst[lst_indexMid:] if s > lst_indexMid else()))
# Out:
# enter first number:1
# enter second number:1
# 8
# 43 2
# {1, 3, 5, 7, 9, 11, 12, 23}
# {}
# ()
