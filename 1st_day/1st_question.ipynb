# %%
#1st way
for i in range(0,11):
  print(5*i)

#2nd way
a=0
b=0
while(a<11):
  b=b+5
  print(b)
  a=a+1

#3rd way
mult = [i for i in range (1,51) if 0==i%5]
print(mult)
# Out:
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50
# 55
# [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
